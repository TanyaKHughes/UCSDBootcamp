# %% [markdown]
# <a href="https://colab.research.google.com/github/TanyaKHughes/UCSDBootcamp/blob/main/ISL_exercises/Ch2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # College Data Set - Ch. 2 ISL book

# %% [markdown]
# ## Get Data and peek at it

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')

# %%
filename = "/content/gdrive/MyDrive/UCSD bootcamp/Colab notebooks/ISL book/"  \
           "Ch 2/College_Data.csv"

print(filename)
data = pd.read_csv(filename)
data
# Out:
# /content/gdrive/MyDrive/UCSD bootcamp/Colab notebooks/ISL book/Ch 2/College_Data.csv
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# ...
